# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "name":["Imran","Rajib","Souvik"],
    "age":[22,35,58],
    "Sex":["male","Male","Male"],})

# %%
df["age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: age, dtype: int64

# %%
df["name"]
# Out:
# 0     Imran
# 1     Rajib
# 2    Souvik
# Name: name, dtype: object

# %%
ages = pd.Series([22,34,12] , name="age")

# %%
ages
# Out:
# 0    22
# 1    34
# 2    12
# Name: age, dtype: int64

# %%
df["age"].max()
# Out:
# np.int64(58)

# %%
ages.max()
# Out:
# np.int64(34)

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
xl = pd.read_excel("PHASEIIREGNINCOMPLETE.XLSX")

# %%
xl
# Out:
#                                   Unnamed: 0 Unnamed: 1             Unnamed: 2
# 0         NETAJI SUBHASH ENGINEERING COLLEGE        NaN                    NaN
# 1   PHASE-II REGISTRATION NOT COMPLETED LIST        NaN                    NaN
# 2                                        NaN        NaN                    NaN
# 3                                      BTECH      PROG.                   NAME
# 4                                        NaN         CE            SAMIM MOLLA
# 5                                        NaN        NaN          SINJAN SANTRA
# 6                                        NaN         EE       INDRASIS JOARDER
# 7                                        NaN        NaN          KISHALAYA NAG
# 8                                        NaN        NaN            ABIR SARKAR
# 9                                        NaN        ECE      SOUMYAJIT CHANDRA
# 10                                       NaN         ME            ANIMESH DAS
# ...

# %%
xl.head(5)
# Out:
#                                  Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0        NETAJI SUBHASH ENGINEERING COLLEGE        NaN          NaN
# 1  PHASE-II REGISTRATION NOT COMPLETED LIST        NaN          NaN
# 2                                       NaN        NaN          NaN
# 3                                     BTECH      PROG.         NAME
# 4                                       NaN         CE  SAMIM MOLLA

# %%
xl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      object
#  1   Unnamed: 1  12 non-null     object
#  2   Unnamed: 2  21 non-null     object
# dtypes: object(3)
# memory usage: 780.0+ bytes

# %%
data = pd.read_csv("Indian_Kids_Screen_Time.csv")
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
aged = data[["Age","Gender"]]

# %%
aged.head()
# Out:
#    Age  Gender
# 0   14    Male
# 1   11  Female
# 2   18  Female
# 3   15  Female
# 4   12  Female

# %%
below_16 = data[data["Age"]==18]
below_16.head(20)
# Out:
#      Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 2     18  Female                      3.73             TV
# 9     18    Male                      3.24         Tablet
# 10    18    Male                      3.53         Tablet
# 29    18    Male                      5.13             TV
# 30    18    Male                      4.45     Smartphone
# 91    18  Female                      6.30         Tablet
# 98    18  Female                      6.40     Smartphone
# 116   18    Male                      3.25         Tablet
# 127   18  Female                      4.59     Smartphone
# 139   18  Female                      4.67             TV
# 142   18  Female                      3.58     Smartphone
# 151   18  Female                      3.05     Smartphone
# 159   18  Female                      4.06     Smartphone
# 167   18  Female                      6.59         Laptop
# 174   18    Male                      5.83     Smartphone
# ...

# %%
git init
git add .
git commit -m "Initial commit - added Jupyter Notebook"
git branch -M main
git remote add originttps:https://github.com/Imran1hp/pandas-.git
git push -u origin main
# Out:
#   Cell In[69], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
