# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran1hp/Machine-Learning/blob/main/Taxi_fare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets --upgrade --quiet
# !pip install plotly matplotlib seaborn --quiet
# !pip install scikit-learn --quiet
# !pip install numpy pandas --quiet

# %%
import opendatasets as od
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_url = 'https://www.kaggle.com/competitions/new-york-city-taxi-fare-prediction/data'

# %%
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: imranlaskar123
# Your Kaggle Key: ··········
# Downloading new-york-city-taxi-fare-prediction.zip to ./new-york-city-taxi-fare-prediction
# 100%|██████████| 1.56G/1.56G [00:24<00:00, 68.6MB/s]
# Extracting archive ./new-york-city-taxi-fare-prediction/new-york-city-taxi-fare-prediction.zip to ./new-york-city-taxi-fare-prediction

# %%
import os

# %%
data_dir='./new-york-city-taxi-fare-prediction'

# %%
os.listdir(data_dir)
# Out:
# ['test.csv',
#  'GCP-Coupons-Instructions.rtf',
#  'sample_submission.csv',
#  'train.csv']

# %%
train_file = data_dir+'/train.csv'

# %%
test_file =data_dir+'/test.csv'

# %%
import pandas as pd

# %%
# !ls -lh {data_dir}
# Out:
# total 5.4G
# -rw-r--r-- 1 root root  486 Sep 30 12:17 GCP-Coupons-Instructions.rtf
# -rw-r--r-- 1 root root 336K Sep 30 12:17 sample_submission.csv
# -rw-r--r-- 1 root root 960K Sep 30 12:17 test.csv
# -rw-r--r-- 1 root root 5.4G Sep 30 12:18 train.csv

# %%
# !head {train_file}
# Out:
# key,fare_amount,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count
# 2009-06-15 17:26:21.0000001,4.5,2009-06-15 17:26:21 UTC,-73.844311,40.721319,-73.84161,40.712278,1
# 2010-01-05 16:52:16.0000002,16.9,2010-01-05 16:52:16 UTC,-74.016048,40.711303,-73.979268,40.782004,1
# 2011-08-18 00:35:00.00000049,5.7,2011-08-18 00:35:00 UTC,-73.982738,40.76127,-73.991242,40.750562,2
# 2012-04-21 04:30:42.0000001,7.7,2012-04-21 04:30:42 UTC,-73.98713,40.733143,-73.991567,40.758092,1
# 2010-03-09 07:51:00.000000135,5.3,2010-03-09 07:51:00 UTC,-73.968095,40.768008,-73.956655,40.783762,1
# 2011-01-06 09:50:45.0000002,12.1,2011-01-06 09:50:45 UTC,-74.000964,40.73163,-73.972892,40.758233,1
# 2012-11-20 20:35:00.0000001,7.5,2012-11-20 20:35:00 UTC,-73.980002,40.751662,-73.973802,40.764842,1
# 2012-01-04 17:22:00.00000081,16.5,2012-01-04 17:22:00 UTC,-73.9513,40.774138,-73.990095,40.751048,1
# 2012-12-03 13:10:00.000000125,9,2012-12-03 13:10:00 UTC,-74.006462,40.726713,-73.993078,40.731628,1

# %%
# !head {test_file}
# Out:
# key,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count
# 2015-01-27 13:08:24.0000002,2015-01-27 13:08:24 UTC,-73.973320007324219,40.7638053894043,-73.981430053710938,40.74383544921875,1
# 2015-01-27 13:08:24.0000003,2015-01-27 13:08:24 UTC,-73.986862182617188,40.719383239746094,-73.998886108398438,40.739200592041016,1
# 2011-10-08 11:53:44.0000002,2011-10-08 11:53:44 UTC,-73.982524,40.75126,-73.979654,40.746139,1
# 2012-12-01 21:12:12.0000002,2012-12-01 21:12:12 UTC,-73.98116,40.767807,-73.990448,40.751635,1
# 2012-12-01 21:12:12.0000003,2012-12-01 21:12:12 UTC,-73.966046,40.789775,-73.988565,40.744427,1
# 2012-12-01 21:12:12.0000005,2012-12-01 21:12:12 UTC,-73.960983,40.765547,-73.979177,40.740053,1
# 2011-10-06 12:10:20.0000001,2011-10-06 12:10:20 UTC,-73.949013,40.773204,-73.959622,40.770893,1
# 2011-10-06 12:10:20.0000003,2011-10-06 12:10:20 UTC,-73.777282,40.646636,-73.985083,40.759368,1
# 2011-10-06 12:10:20.0000002,2011-10-06 12:10:20 UTC,-74.014099,40.709638,-73.995106,40.741365,1

# %%
# !wc -l {train_file}
# Out:
# 55423856 ./new-york-city-taxi-fare-prediction/train.csv

# %%
# !wc -l {test_file}
# Out:
# 9914 ./new-york-city-taxi-fare-prediction/test.csv

# %%
import pandas as pd
import random

# %%
sample_frac =0.01

# %%
selected_cols = 'fare_amount,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count'

# %%
dtype = {
    'fare_amount': 'float32',
    'pickup_longitude': 'float32',
    'pickup_latitude': 'float32',
    'dropoff_longitude': 'float32',
    'dropoff_latitude': 'float32',
    'passenger_count': 'uint8'
}

def skip_row(row_idx):
  if row_idx ==0:
    return False
  return random.random()>sample_frac
random.seed(42)
df= pd.read_csv(train_file,usecols=selected_cols.split(','),dtype=dtype,parse_dates =['pickup_datetime'] ,skiprows=skip_row)

# %%
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               4.0 2014-12-06 20:36:22+00:00        -73.979813
# 1               8.0 2013-01-17 17:22:00+00:00          0.000000
# 2               8.9 2011-06-15 18:07:00+00:00        -73.996330
# 3               6.9 2009-12-14 12:33:00+00:00        -73.982430
# 4               7.0 2013-11-06 11:26:54+00:00        -73.959061
# ...             ...                       ...               ...
# 552445         45.0 2014-02-06 23:59:45+00:00        -73.973587
# 552446         22.5 2015-01-05 15:29:08+00:00        -73.935928
# 552447          4.5 2013-02-17 22:27:00+00:00        -73.992531
# 552448         14.5 2013-01-27 12:41:00+00:00        -74.012115
# 552449          6.0 2014-10-18 07:51:00+00:00        -73.997681
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.751904         -73.979446         40.755482                1
# 1              0.000000           0.000000          0.000000                2
# 2             40.753223         -73.978897         40.766964                3
# 3             40.745747         -73.982430         40.745747                1
# 4             40.781059         -73.962059         40.768604                1
# ...                 ...                ...               ...              ...
# 552445        40.747669         -73.999916         40.602894                1
# 552446        40.799656         -73.985710         40.726952                2
# 552447        40.748619         -73.998436         40.740143                1
# 552448        40.706635         -73.988724         40.756218                1
# 552449        40.724380         -73.994148         40.717796                1
#
# [552450 rows x 7 columns]

# %%
test_df  = pd.read_csv(test_file,dtype=dtype,parse_dates=['pickup_datetime'])

# %%
test_df
# Out:
#                               key           pickup_datetime  pickup_longitude  \
# 0     2015-01-27 13:08:24.0000002 2015-01-27 13:08:24+00:00        -73.973320
# 1     2015-01-27 13:08:24.0000003 2015-01-27 13:08:24+00:00        -73.986862
# 2     2011-10-08 11:53:44.0000002 2011-10-08 11:53:44+00:00        -73.982521
# 3     2012-12-01 21:12:12.0000002 2012-12-01 21:12:12+00:00        -73.981163
# 4     2012-12-01 21:12:12.0000003 2012-12-01 21:12:12+00:00        -73.966049
# ...                           ...                       ...               ...
# 9909  2015-05-10 12:37:51.0000002 2015-05-10 12:37:51+00:00        -73.968124
# 9910  2015-01-12 17:05:51.0000001 2015-01-12 17:05:51+00:00        -73.945511
# 9911  2015-04-19 20:44:15.0000001 2015-04-19 20:44:15+00:00        -73.991600
# 9912  2015-01-31 01:05:19.0000005 2015-01-31 01:05:19+00:00        -73.985573
# 9913  2015-01-18 14:06:23.0000006 2015-01-18 14:06:23+00:00        -73.988022
#
#       pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0           40.763805         -73.981430         40.743835                1
# 1           40.719383         -73.998886         40.739201                1
# 2           40.751259         -73.979652         40.746140                1
# 3           40.767807         -73.990448         40.751637                1
# 4           40.789776         -73.988564         40.744427                1
# ...               ...                ...               ...              ...
# 9909        40.796997         -73.955643         40.780388                6
# 9910        40.803600         -73.960213         40.776371                6
# 9911        40.726608         -73.789742         40.647011                6
# 9912        40.735432         -73.939178         40.801731                6
# 9913        40.754070         -74.000282         40.759220                6
#
# [9914 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552450 entries, 0 to 552449
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        552450 non-null  float32
#  1   pickup_datetime    552450 non-null  datetime64[ns, UTC]
#  2   pickup_longitude   552450 non-null  float32
#  3   pickup_latitude    552450 non-null  float32
#  4   dropoff_longitude  552450 non-null  float32
#  5   dropoff_latitude   552450 non-null  float32
#  6   passenger_count    552450 non-null  uint8
# dtypes: datetime64[ns, UTC](1), float32(5), uint8(1)
# memory usage: 15.3 MB

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  552450.000000     552450.000000    552450.000000      552450.000000
# mean       11.354059        -72.497063        39.910500         -72.504326
# std         9.810809         11.622035         8.041162          12.065184
# min       -52.000000      -1183.362793     -3084.490234       -3356.729736
# 25%         6.000000        -73.992020        40.734875         -73.991425
# 50%         8.500000        -73.981819        40.752621         -73.980179
# 75%        12.500000        -73.967155        40.767036         -73.963737
# max       499.000000       2420.209473       404.983337        2467.752686
#
#        dropoff_latitude  passenger_count
# count     552450.000000    552450.000000
# mean          39.934265         1.684983
# std            9.226158         1.337664
# min        -2073.150635         0.000000
# 25%           40.733990         1.000000
# 50%           40.753101         1.000000
# 75%           40.768059         2.000000
# max         3351.403076       208.000000

# %%
df.pickup_datetime.min(),df.pickup_datetime.max()
# Out:
# (Timestamp('2009-01-01 00:11:46+0000', tz='UTC'),
#  Timestamp('2015-06-30 23:59:54+0000', tz='UTC'))

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9914 entries, 0 to 9913
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                9914 non-null   object
#  1   pickup_datetime    9914 non-null   datetime64[ns, UTC]
#  2   pickup_longitude   9914 non-null   float32
#  3   pickup_latitude    9914 non-null   float32
#  4   dropoff_longitude  9914 non-null   float32
#  5   dropoff_latitude   9914 non-null   float32
#  6   passenger_count    9914 non-null   uint8
#  7   distance_km        9914 non-null   float32
# dtypes: datetime64[ns, UTC](1), float32(5), object(1), uint8(1)
# memory usage: 358.3+ KB

# %%
test_df.describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count       9914.000000      9914.000000        9914.000000       9914.000000
# mean         -73.974716        40.751041         -73.973656         40.751740
# std            0.042799         0.033542           0.039093          0.035436
# min          -74.252190        40.573143         -74.263245         40.568974
# 25%          -73.992500        40.736125         -73.991249         40.735253
# 50%          -73.982327        40.753052         -73.980015         40.754065
# 75%          -73.968012        40.767113         -73.964062         40.768757
# max          -72.986534        41.709557         -72.990967         41.696682
#
#        passenger_count
# count      9914.000000
# mean          1.671273
# std           1.278747
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           6.000000

# %%
test_df.pickup_datetime.min(), test_df.pickup_datetime.max()
# Out:
# (Timestamp('2009-01-01 11:04:24+0000', tz='UTC'),
#  Timestamp('2015-06-30 20:03:50+0000', tz='UTC'))

# %%
df.head(20)
# Out:
#     fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0           4.0 2014-12-06 20:36:22+00:00        -73.979813        40.751904
# 1           8.0 2013-01-17 17:22:00+00:00          0.000000         0.000000
# 2           8.9 2011-06-15 18:07:00+00:00        -73.996330        40.753223
# 3           6.9 2009-12-14 12:33:00+00:00        -73.982430        40.745747
# 4           7.0 2013-11-06 11:26:54+00:00        -73.959061        40.781059
# 5          15.5 2014-12-08 01:00:16+00:00        -73.957672        40.717888
# 6           6.0 2012-09-26 13:14:47+00:00        -73.964485        40.764431
# 7          21.0 2014-01-29 22:41:00+00:00        -73.978554        40.766716
# 8          20.5 2012-09-13 11:31:00+00:00        -73.986458        40.751526
# 9          16.5 2012-02-21 12:13:11+00:00        -74.010895        40.714424
# 10          9.0 2014-09-22 17:08:00+00:00        -73.998009        40.756081
# 11          3.7 2012-08-01 02:29:00+00:00        -73.984177        40.758892
# 12          6.9 2011-05-23 08:06:09+00:00        -73.962570        40.772598
# 13          5.3 2009-10-09 09:57:38+00:00        -73.975708        40.753517
# 14          4.9 2011-03-29 09:29:45+00:00        -74.001495        40.730991
# 15          9.7 2012-03-24 11:45:12+00:00        -73.976418        40.760155
# 16          9.5 2015-06-04 06:44:57+00:00        -73.977486        40.746696
# 17          6.0 2013-01-08 08:21:00+00:00        -74.002701        40.728447
# 18          7.7 2010-04-26 17:52:00+00:00        -73.967964        40.764812
# 19          4.1 2011-06-05 02:38:00+00:00        -73.957741        40.713249
#
#     dropoff_longitude  dropoff_latitude  passenger_count
# 0          -73.979446         40.755482                1
# 1            0.000000          0.000000                2
# 2          -73.978897         40.766964                3
# 3          -73.982430         40.745747                1
# 4          -73.962059         40.768604                1
# 5          -73.942581         40.686398                1
# 6          -73.956573         40.779854                1
# 7          -74.016197         40.711052                6
# 8          -73.953735         40.787724                1
# 9          -73.983368         40.756248                1
# 10         -73.982727         40.773338                1
# 11         -73.989830         40.752625                1
# 12         -73.956100         40.783684                2
# 13         -73.979263         40.758942                4
# 14         -73.993980         40.741508                1
# 15         -74.006989         40.741589                1
# 16         -73.957748         40.765636                2
# 17         -73.994331         40.736301                1
# 18         -73.948090         40.778896                1
# 19         -73.961967         40.719734                2

# %%
import numpy as np

def distance_cal(lon1,lat1,lon2,lat2):
  R = 6371;
  lon1,lat1,lon2,lat2 = map(np.radians,[lon1,lat1,lon2,lat2])
  dlon = lon2 -lon1
  dlat = lat2 -lat1
  a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
  c = 2 * np.atan2(np.sqrt(a),np.sqrt(1-a))
  return  R * c

# %%
df['distance_km'] =distance_cal(df['pickup_longitude'],df['pickup_latitude'],df['dropoff_longitude'],df['dropoff_latitude'])

# %%
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               4.0 2014-12-06 20:36:22+00:00        -73.979813
# 1               8.0 2013-01-17 17:22:00+00:00          0.000000
# 2               8.9 2011-06-15 18:07:00+00:00        -73.996330
# 3               6.9 2009-12-14 12:33:00+00:00        -73.982430
# 4               7.0 2013-11-06 11:26:54+00:00        -73.959061
# ...             ...                       ...               ...
# 552445         45.0 2014-02-06 23:59:45+00:00        -73.973587
# 552446         22.5 2015-01-05 15:29:08+00:00        -73.935928
# 552447          4.5 2013-02-17 22:27:00+00:00        -73.992531
# 552448         14.5 2013-01-27 12:41:00+00:00        -74.012115
# 552449          6.0 2014-10-18 07:51:00+00:00        -73.997681
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.751904         -73.979446         40.755482                1
# 1              0.000000           0.000000          0.000000                2
# 2             40.753223         -73.978897         40.766964                3
# 3             40.745747         -73.982430         40.745747                1
# 4             40.781059         -73.962059         40.768604                1
# ...                 ...                ...               ...              ...
# 552445        40.747669         -73.999916         40.602894                1
# 552446        40.799656         -73.985710         40.726952                2
# 552447        40.748619         -73.998436         40.740143                1
# 552448        40.706635         -73.988724         40.756218                1
# 552449        40.724380         -73.994148         40.717796                1
#
#         distance_km
# 0          0.399180
# 1          0.000000
# 2          2.119035
# 3          0.000000
# 4          1.407744
# ...             ...
# 552445    16.250786
# 552446     9.106701
# 552447     1.065598
# 552448     5.855228
# 552449     0.790310
#
# [552450 rows x 8 columns]

# %%
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               4.0 2014-12-06 20:36:22+00:00        -73.979813
# 1               8.0 2013-01-17 17:22:00+00:00          0.000000
# 2               8.9 2011-06-15 18:07:00+00:00        -73.996330
# 3               6.9 2009-12-14 12:33:00+00:00        -73.982430
# 4               7.0 2013-11-06 11:26:54+00:00        -73.959061
# ...             ...                       ...               ...
# 552445         45.0 2014-02-06 23:59:45+00:00        -73.973587
# 552446         22.5 2015-01-05 15:29:08+00:00        -73.935928
# 552447          4.5 2013-02-17 22:27:00+00:00        -73.992531
# 552448         14.5 2013-01-27 12:41:00+00:00        -74.012115
# 552449          6.0 2014-10-18 07:51:00+00:00        -73.997681
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.751904         -73.979446         40.755482                1
# 1              0.000000           0.000000          0.000000                2
# 2             40.753223         -73.978897         40.766964                3
# 3             40.745747         -73.982430         40.745747                1
# 4             40.781059         -73.962059         40.768604                1
# ...                 ...                ...               ...              ...
# 552445        40.747669         -73.999916         40.602894                1
# 552446        40.799656         -73.985710         40.726952                2
# 552447        40.748619         -73.998436         40.740143                1
# 552448        40.706635         -73.988724         40.756218                1
# 552449        40.724380         -73.994148         40.717796                1
#
#         distance_km
# 0          0.399180
# 1          0.000000
# 2          2.119035
# 3          0.000000
# 4          1.407744
# ...             ...
# 552445    16.250786
# 552446     9.106701
# 552447     1.065598
# 552448     5.855228
# 552449     0.790310
#
# [552450 rows x 8 columns]

# %%
test_df['distance_km'] =distance_cal(test_df['pickup_longitude'],test_df['pickup_latitude'],test_df['dropoff_longitude'],test_df['dropoff_latitude'])

# %%
test_df
# Out:
#                               key           pickup_datetime  pickup_longitude  \
# 0     2015-01-27 13:08:24.0000002 2015-01-27 13:08:24+00:00        -73.973320
# 1     2015-01-27 13:08:24.0000003 2015-01-27 13:08:24+00:00        -73.986862
# 2     2011-10-08 11:53:44.0000002 2011-10-08 11:53:44+00:00        -73.982521
# 3     2012-12-01 21:12:12.0000002 2012-12-01 21:12:12+00:00        -73.981163
# 4     2012-12-01 21:12:12.0000003 2012-12-01 21:12:12+00:00        -73.966049
# ...                           ...                       ...               ...
# 9909  2015-05-10 12:37:51.0000002 2015-05-10 12:37:51+00:00        -73.968124
# 9910  2015-01-12 17:05:51.0000001 2015-01-12 17:05:51+00:00        -73.945511
# 9911  2015-04-19 20:44:15.0000001 2015-04-19 20:44:15+00:00        -73.991600
# 9912  2015-01-31 01:05:19.0000005 2015-01-31 01:05:19+00:00        -73.985573
# 9913  2015-01-18 14:06:23.0000006 2015-01-18 14:06:23+00:00        -73.988022
#
#       pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0           40.763805         -73.981430         40.743835                1
# 1           40.719383         -73.998886         40.739201                1
# 2           40.751259         -73.979652         40.746140                1
# 3           40.767807         -73.990448         40.751637                1
# 4           40.789776         -73.988564         40.744427                1
# ...               ...                ...               ...              ...
# 9909        40.796997         -73.955643         40.780388                6
# 9910        40.803600         -73.960213         40.776371                6
# 9911        40.726608         -73.789742         40.647011                6
# 9912        40.735432         -73.939178         40.801731                6
# 9913        40.754070         -74.000282         40.759220                6
#
#       distance_km
# 0        2.323358
# 1        2.425299
# 2        0.618403
# 3        1.960912
# 4        5.387211
# ...           ...
# 9909     2.124599
# 9910     3.271138
# 9911    19.183577
# 9912     8.343392
# 9913     1.180814
#
# [9914 rows x 8 columns]

# %%
df.distance_km.describe()
# Out:
# count    552450.000000
# mean         20.193258
# std         375.652405
# min           0.000000
# 25%           1.213912
# 50%           2.119152
# 75%           3.879649
# max       16924.054688
# Name: distance_km, dtype: float64

# %%
test_df.distance_km.describe()
# Out:
# count    9914.000000
# mean        3.435373
# std         3.972377
# min         0.000000
# 25%         1.298076
# 50%         2.217041
# 75%         4.045591
# max        99.996071
# Name: distance_km, dtype: float64

# %%
plt.title("Age vs Charges")
sns.barplot(data=df,x="passenger_count",y="fare_amount",)
# Out:
# <Axes: title={'center': 'Age vs Charges'}, xlabel='passenger_count', ylabel='fare_amount'>

# %%
from sklearn.model_selection import train_test_split

# %%
train_df , val_df = train_test_split(df, test_size=0.2,random_state=42)

# %%
len(train_df),len(val_df)
# Out:
# (441960, 110490)

# %%
train_df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 353352          6.0 2015-04-12 03:40:38+00:00        -73.993652
# 360070          3.7 2011-01-26 19:21:00+00:00        -73.993805
# 372609         10.0 2012-10-03 10:40:17+00:00        -73.959160
# 550895          8.9 2012-03-14 13:44:27+00:00        -73.952187
# 444151          7.3 2012-02-05 15:33:00+00:00        -73.977112
# ...             ...                       ...               ...
# 110268          9.3 2009-09-06 16:12:00+00:00        -73.987152
# 259178         18.5 2009-04-12 09:58:56+00:00        -73.972656
# 365838         10.1 2012-07-12 19:30:00+00:00        -73.991982
# 131932         10.9 2011-02-17 18:33:00+00:00        -73.969055
# 121958          9.5 2015-01-14 17:35:03+00:00        -73.983040
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 353352        40.741543         -73.977974         40.742352                4
# 360070        40.724579         -73.993805         40.724579                1
# 372609        40.780750         -73.969116         40.761230                1
# 550895        40.783951         -73.978645         40.772602                1
# 444151        40.746834         -73.991104         40.750404                2
# ...                 ...                ...               ...              ...
# 110268        40.750633         -73.979073         40.763168                1
# 259178        40.764042         -74.013176         40.707840                2
# 365838        40.749767         -73.989845         40.720551                3
# 131932        40.761398         -73.990814         40.751328                1
# 121958        40.742142         -74.002510         40.727650                1
#
#         distance_km
# 353352     1.324242
# 360070     0.000000
# 372609     2.326965
# 550895     2.560520
# 444151     1.244048
# ...             ...
# 110268     1.550950
# 259178     7.121000
# 365838     3.253644
# 131932     2.147450
# 121958     2.299576
#
# [441960 rows x 8 columns]

# %%
val_df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 15971     14.000000 2015-05-19 09:27:24+00:00        -73.995834
# 149839     6.500000 2010-04-10 15:07:51+00:00        -73.977386
# 515867    49.570000 2009-07-25 14:11:00+00:00        -73.983910
# 90307     49.700001 2011-11-11 19:09:21+00:00        -73.790794
# 287032     8.500000 2015-03-09 18:06:44+00:00        -73.976593
# ...             ...                       ...               ...
# 467556     6.100000 2010-04-03 20:16:00+00:00        -73.968567
# 19482      7.300000 2010-04-26 00:32:00+00:00        -73.986725
# 186063     4.500000 2009-05-21 08:13:16+00:00          0.000000
# 382260    32.900002 2011-07-07 16:10:59+00:00        -73.980057
# 18838     11.500000 2015-02-27 12:10:08+00:00        -73.955406
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 15971         40.759190         -73.973679         40.739086                1
# 149839        40.738335         -73.976143         40.751205                1
# 515867        40.749470         -73.787170         40.646645                1
# 90307         40.643463         -73.972252         40.690182                1
# 287032        40.761944         -73.991463         40.750309                2
# ...                 ...                ...               ...              ...
# 467556        40.761238         -73.983406         40.750019                3
# 19482         40.755920         -73.985855         40.731171                1
# 186063         0.000000           0.000000          0.000000                1
# 382260        40.760334         -73.872589         40.774300                1
# 18838         40.782417         -73.960434         40.767666                1
#
#         distance_km
# 15971      2.911621
# 149839     1.434692
# 515867    20.145134
# 90307     16.162235
# 287032     1.800684
# ...             ...
# 467556     1.766068
# 19482      2.752970
# 186063     0.000000
# 382260     9.182614
# 18838      1.694216
#
# [110490 rows x 8 columns]

# %%
train_df.columns
# Out:
# Index(['fare_amount', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count',
#        'distance_km'],
#       dtype='object')

# %%
input_cols = ['pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','passenger_count','distance_km']

# %%
target_col =['fare_amount']

# %%
train_inputs = train_df[input_cols]

# %%
train_targets = train_df[target_col]

# %%
val_inputs = val_df[input_cols]

# %%
val_targets = val_df[target_col]

# %%
val_targets
# Out:
#         fare_amount
# 15971     14.000000
# 149839     6.500000
# 515867    49.570000
# 90307     49.700001
# 287032     8.500000
# ...             ...
# 467556     6.100000
# 19482      7.300000
# 186063     4.500000
# 382260    32.900002
# 18838     11.500000
#
# [110490 rows x 1 columns]

# %%
test_inputs = test_df[input_cols]

# %%
test_inputs
# Out:
#       pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0           -73.973320        40.763805         -73.981430         40.743835
# 1           -73.986862        40.719383         -73.998886         40.739201
# 2           -73.982521        40.751259         -73.979652         40.746140
# 3           -73.981163        40.767807         -73.990448         40.751637
# 4           -73.966049        40.789776         -73.988564         40.744427
# ...                ...              ...                ...               ...
# 9909        -73.968124        40.796997         -73.955643         40.780388
# 9910        -73.945511        40.803600         -73.960213         40.776371
# 9911        -73.991600        40.726608         -73.789742         40.647011
# 9912        -73.985573        40.735432         -73.939178         40.801731
# 9913        -73.988022        40.754070         -74.000282         40.759220
#
#       passenger_count  distance_km
# 0                   1     2.323358
# 1                   1     2.425299
# 2                   1     0.618403
# 3                   1     1.960912
# 4                   1     5.387211
# ...               ...          ...
# 9909                6     2.124599
# 9910                6     3.271138
# 9911                6    19.183577
# 9912                6     8.343392
# 9913                6     1.180814
#
# [9914 rows x 6 columns]

# %%
class MeanRegressor():
  def fit(self,inputs,targets):
    self.mean =targets.mean()
  def predict(self,inputs):
    return np.full(inputs.shape[0],self.mean)

# %%
mean_model = MeanRegressor()

# %%
mean_model.fit(train_inputs,train_targets)

# %%
mean_model.mean
# Out:
# fare_amount    11.354714
# dtype: float32

# %%
train_preds = mean_model.predict(train_inputs)

# %%
train_preds
# Out:
# array([11.354714, 11.354714, 11.354714, ..., 11.354714, 11.354714,
#        11.354714], dtype=float32)

# %%
val_preds =  mean_model.predict(val_inputs)

# %%
val_preds
# Out:
# array([11.354714, 11.354714, 11.354714, ..., 11.354714, 11.354714,
#        11.354714], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error

# %%
def rmse(targets,preds):
  return np.sqrt(mean_squared_error(targets,preds))

# %%
train_rmse = rmse(train_targets,train_preds)

# %%
train_rmse
# Out:
# np.float64(9.789781840838485)

# %%
val_rmse = rmse(val_targets,val_preds)
val_rmse
# Out:
# np.float64(9.89995425435296)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(train_inputs,train_targets)
# Out:
# LinearRegression()

# %%
train_preds = linear_model.predict(train_inputs)
train_preds
# Out:
# array([[11.341894],
#        [11.340974],
#        [11.34259 ],
#        ...,
#        [11.343234],
#        [11.342466],
#        [11.342571]], dtype=float32)

# %%
val_preds = linear_model.predict(val_inputs)
val_preds
# Out:
# array([[11.342997],
#        [11.34197 ],
#        [11.354969],
#        ...,
#        [11.341513],
#        [11.347353],
#        [11.342152]], dtype=float32)

# %%
train_rmse = rmse(train_targets,train_preds)
train_rmse
# Out:
# np.float64(9.786379897916678)

# %%
val_rmse = rmse(val_targets,val_preds)
val_rmse
# Out:
# np.float64(9.895012001620161)
